# %% [markdown]
# ## Data Mining and cleaning for Kinase Inhibitor Data
#
# After deciding to obtain our kinase inhibitor information from PKIDB we went about extracting this information from the website and putting it into a CSV file. From here we need to clean this data and extract further information in order for our table to be suitable enough to import into our database.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests
import re

# %%
#We read our CSV file using pandas to make it a dataframe object.
df = pd.read_csv('PKIDB.csv', header=0, encoding = 'unicode_escape')

df
# Out:
#           INN_Name  BrandName  Phase            Applicants  \
# 0      Abemaciclib   Verzenio    4.0             Eli Lilly
# 1      Abivertinib        NaN    3.0      ACEA Biosciences
# 2    Acalabrutinib  Calquence    4.0           Astrazeneca
# 3         Acalisib        NaN    2.0       Gilead Sciences
# 4       Acumapimod        NaN    2.0       Mereo BioPharma
# ..             ...        ...    ...                   ...
# 213    Vistusertib        NaN    2.0           Astrazeneca
# 214     Volasertib        NaN    3.0  Boehringer Ingelheim
# 215     Voruciclib        NaN    2.0   Piramal Enterprises
# 216     Voxtalisib        NaN    2.0                Sanofi
# 217   Zanubrutinib        NaN    4.0               BeiGene
#
#                                                  Links  LigID           pdbID  \
# 0    ChemSpider\nChEMBL\nPubChem\nDrugBank\nRCSB\nP...  '6ZV'            5l2s
# 1    ChemSpider\nPubChem\nDrugBank\nGuide to Pharma...    NaN             NaN
# 2    ChemSpider\nChEMBL\nPubChem\nDrugBank\nGuide t...    NaN             NaN
# 3    ChemSpider\nPubChem\nDrugBank\nGuide to Pharma...    NaN             NaN
# 4    ChemSpider\nPubChem\nDrugBank\nGuide to Pharma...    NaN             NaN
# ..                                                 ...    ...             ...
# 213  ChemSpider\nChEMBL\nPubChem\nDrugBank\nGuide t...    NaN             NaN
# 214  ChemSpider\nChEMBL\nDrugBank\nRCSB\nPDBe\nGuid...  'IBI'  3fc2 5v67 5vbr
# 215  ChemSpider\nChEMBL\nPubChem\nDrugBank\nGuide t...    NaN             NaN
# 216  ChemSpider\nChEMBL\nPubChem\nDrugBank\nZINC\nF...    NaN             NaN
# 217             ChemSpider\nChEMBL\nPubChem\nBindingDB    NaN             NaN
#
#      Type  RoF     MW  ...                                        Indications  \
# 0     1.0    1  506.3  ...  On September 28, 2017, the Food and Drug Admin...
# 1     NaN    0  487.2  ...  AC0010 is an orally active, irreversible EGFR ...
# 2     NaN    0  465.2  ...  Acalabrutinib is currently indicated for the t...
# 3     NaN    0  401.1  ...                                                NaN
# 4     NaN    0  385.2  ...                                                NaN
# ..    ...  ...    ...  ...                                                ...
# 213   NaN    0  462.2  ...                                                NaN
# 214   1.0    1  618.4  ...                                                NaN
# 215   NaN    0  469.1  ...                                                NaN
# 216   NaN    0  270.1  ...                                                NaN
# 217   NaN    0  471.2  ...  Zanubrutinib (BGB-3111) is a potent, selective...
#
#                             Targets  Kinase families  \
# 0                        CDK4\nCDK6             CMGC
# 1                               NaN              NaN
# 2                               BTK              Tyr
# 3                            PIK3CA         Atypical
# 4    MAPK14\nMAPK11\nMAPK13\nMAPK12             CMGC
# ..                              ...              ...
# 213                            MTOR         Atypical
# 214                            PLK1            Other
# 215                            CDK4             CMGC
# 216                    PIK3CA\nMTOR         Atypical
# 217                             NaN              NaN
#
#                              Canonical_Smiles_InChiKey  First_Approval  \
# 0    Smiles=CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc...          2017.0
# 1    Smiles=CN1CCN(CC1)c2ccc(cc2F)Nc3nc4c(cc[nH]4)c...             NaN
# 2    Smiles=CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4c...          2017.0
# 3    Smiles=C[C@@H](c1nc2ccc(cc2c(=O)n1c3ccccc3)F)N...             NaN
# 4    Smiles=Cc1ccc(cc1n2c(c(cn2)C(=O)c3cccc(c3)C#N)...             NaN
# ..                                                 ...             ...
# 213  Smiles=C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@...             NaN
# 214  Smiles=CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3...             NaN
# 215  Smiles=CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=...             NaN
# 216  Smiles=CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C\...             NaN
# 217  Smiles=C=CC(=O)N1CCC(CC1)C2CCNc3n2nc(c3C(=O)N)...          2019.0
#
#          SC_Patent            Chirality                           Synonyms  \
# 0    US-7855211-B2     Achiral Molecule  Verzenio\nAbemaciclib\nLY-2835219
# 1              NaN                  NaN                   AC0010\nAvitinib
# 2    US-9290504-B2  Single Stereoisomer  Calquence\nACP-196\nAcalabrutinib
# 3              NaN  Single Stereoisomer                            CAL-120
# 4              NaN  Single Stereoisomer                                NaN
# ..             ...                  ...                                ...
# 213            NaN  Single Stereoisomer     AZD-2014\nAZD2014\nVistusertib
# 214            NaN  Single Stereoisomer                BI-6727\nVolasertib
# 215            NaN  Single Stereoisomer                                NaN
# 216            NaN     Achiral Molecule     SAR-245409\nVoxtalisib\nXL-765
# 217            NaN                  NaN             BGB-3111\nZANUBRUTINIB
#
#     FDA approved  Melting points (°C)
# 0              Y                  NaN
# 1            NaN                  NaN
# 2              Y                  NaN
# 3            NaN                  NaN
# 4            NaN                  NaN
# ..           ...                  ...
# 213          NaN                  NaN
# 214          NaN                  NaN
# 215          NaN                  NaN
# 216          NaN                  NaN
# 217            Y                  NaN
#
# [218 rows x 25 columns]

# %% [markdown]
# The format that our table presently is in, is not in a format we need for our table. Presently, the kinases in the targets column are in a list format per inhibitor. However, for our database we need the targets to be list in their own indvidual rows. So we need to create a new dataframe to reformat our data in this way.

# %%
#So we take the values under the INN_Name and Targets column and place them into a new dataframe.
INN = df.INN_Name
TARGETS = df.Targets
df1 = pd.DataFrame({'INN_Name': INN, 'Targets': TARGETS})
df1
# Out:
#           INN_Name                         Targets
# 0      Abemaciclib                      CDK4\nCDK6
# 1      Abivertinib                             NaN
# 2    Acalabrutinib                             BTK
# 3         Acalisib                          PIK3CA
# 4       Acumapimod  MAPK14\nMAPK11\nMAPK13\nMAPK12
# ..             ...                             ...
# 213    Vistusertib                            MTOR
# 214     Volasertib                            PLK1
# 215     Voruciclib                            CDK4
# 216     Voxtalisib                    PIK3CA\nMTOR
# 217   Zanubrutinib                             NaN
#
# [218 rows x 2 columns]

# %%
#We then re-format our new dataframe so that all of our Kinase targets are split and placed into their own separate rows.
df1 = \
(df1.set_index(df1.columns.drop('Targets',2).tolist()) #set the dataframe index to our Targets column as a list and drop it
   .Targets.str.split('\n', expand=True) #we then separate the contents of the Targets column by each new line (i.e. each kinase)
   .stack() #we then stack the dataframe from columns to index
   .reset_index() #reset our index
   .rename(columns={0:'Targets'}) #then we rename our index column back to 'Targets'
   .loc[:, df1.columns] #we then rematch the INN_Names to out new Targets column to get the final basis for our newly formatted 
                        # dataframe
)

df1
# Out:
#           INN_Name Targets
# 0      Abemaciclib    CDK4
# 1      Abemaciclib    CDK6
# 2    Acalabrutinib     BTK
# 3         Acalisib  PIK3CA
# 4       Acumapimod  MAPK14
# ..             ...     ...
# 488    Vistusertib    MTOR
# 489     Volasertib    PLK1
# 490     Voruciclib    CDK4
# 491     Voxtalisib  PIK3CA
# 492     Voxtalisib    MTOR
#
# [493 rows x 2 columns]

# %% [markdown]
# Now that we have our initial data in the correct format we now need to put the rest of our data of interest into the same format of this new dataframe.

# %%
#We remove all of the column from our first dataframe so that only the remaining data from the table matches what we want
#in our database.
df = df.drop(columns=['BrandName', 'Phase', 'Applicants', 'Links', 'LigID', 'pdbID', 'Type', 'Indications', 'Targets',
                      'Kinase families', 'First_Approval', 'SC_Patent', 'Chirality', 'Synonyms', 'FDA approved', 
                      'Melting points (°C)'])

df
# Out:
#           INN_Name  RoF     MW  LogP   TPSA  HBA  HBD  NRB  \
# 0      Abemaciclib    1  506.3   4.9   75.0    8    1    7
# 1      Abivertinib    0  487.2   4.5   98.4    7    3    7
# 2    Acalabrutinib    0  465.2   3.3  118.5    7    2    4
# 3         Acalisib    0  401.1   3.4  101.4    7    2    4
# 4       Acumapimod    0  385.2   2.8  113.8    6    2    5
# ..             ...  ...    ...   ...    ...  ...  ...  ...
# 213    Vistusertib    0  462.2   2.5   92.7    8    1    4
# 214     Volasertib    1  618.4   4.3  106.2    9    2   10
# 215     Voruciclib    0  469.1   4.3   94.1    6    3    3
# 216     Voxtalisib    0  270.1   1.1  102.5    6    2    2
# 217   Zanubrutinib    0  471.2   4.2  102.5    6    2    6
#
#                              Canonical_Smiles_InChiKey
# 0    Smiles=CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc...
# 1    Smiles=CN1CCN(CC1)c2ccc(cc2F)Nc3nc4c(cc[nH]4)c...
# 2    Smiles=CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4c...
# 3    Smiles=C[C@@H](c1nc2ccc(cc2c(=O)n1c3ccccc3)F)N...
# 4    Smiles=Cc1ccc(cc1n2c(c(cn2)C(=O)c3cccc(c3)C#N)...
# ..                                                 ...
# 213  Smiles=C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@...
# 214  Smiles=CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3...
# 215  Smiles=CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=...
# 216  Smiles=CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C\...
# 217  Smiles=C=CC(=O)N1CCC(CC1)C2CCNc3n2nc(c3C(=O)N)...
#
# [218 rows x 9 columns]

# %%
#Smiles and InChi key information for each inhibitor is something we would like in two separate columns so we split the contents
#of the Canonical_Smiles_InChiKey by a new line (seaprator between Smile and InChi info in the column) and we put it into two
#new columns.
df[['Smiles','InChi_Key']] = df.Canonical_Smiles_InChiKey.str.split("\n",expand=True,)
df
# Out:
#           INN_Name  RoF     MW  LogP   TPSA  HBA  HBD  NRB  \
# 0      Abemaciclib    1  506.3   4.9   75.0    8    1    7
# 1      Abivertinib    0  487.2   4.5   98.4    7    3    7
# 2    Acalabrutinib    0  465.2   3.3  118.5    7    2    4
# 3         Acalisib    0  401.1   3.4  101.4    7    2    4
# 4       Acumapimod    0  385.2   2.8  113.8    6    2    5
# ..             ...  ...    ...   ...    ...  ...  ...  ...
# 213    Vistusertib    0  462.2   2.5   92.7    8    1    4
# 214     Volasertib    1  618.4   4.3  106.2    9    2   10
# 215     Voruciclib    0  469.1   4.3   94.1    6    3    3
# 216     Voxtalisib    0  270.1   1.1  102.5    6    2    2
# 217   Zanubrutinib    0  471.2   4.2  102.5    6    2    6
#
#                              Canonical_Smiles_InChiKey  \
# 0    Smiles=CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc...
# 1    Smiles=CN1CCN(CC1)c2ccc(cc2F)Nc3nc4c(cc[nH]4)c...
# 2    Smiles=CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4c...
# 3    Smiles=C[C@@H](c1nc2ccc(cc2c(=O)n1c3ccccc3)F)N...
# 4    Smiles=Cc1ccc(cc1n2c(c(cn2)C(=O)c3cccc(c3)C#N)...
# ..                                                 ...
# 213  Smiles=C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@...
# 214  Smiles=CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3...
# 215  Smiles=CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=...
# 216  Smiles=CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C\...
# 217  Smiles=C=CC(=O)N1CCC(CC1)C2CCNc3n2nc(c3C(=O)N)...
#
#                                                 Smiles  \
# 0    Smiles=CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc...
# 1    Smiles=CN1CCN(CC1)c2ccc(cc2F)Nc3nc4c(cc[nH]4)c...
# 2    Smiles=CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4c...
# 3    Smiles=C[C@@H](c1nc2ccc(cc2c(=O)n1c3ccccc3)F)N...
# 4    Smiles=Cc1ccc(cc1n2c(c(cn2)C(=O)c3cccc(c3)C#N)...
# ..                                                 ...
# 213  Smiles=C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@...
# 214  Smiles=CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3...
# 215  Smiles=CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=...
# 216      Smiles=CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
# 217  Smiles=C=CC(=O)N1CCC(CC1)C2CCNc3n2nc(c3C(=O)N)...
#
#                                 InChi_Key
# 0    InChiKey=UZWDCWONPYILKI-UHFFFAOYSA-N
# 1    InChiKey=UOFYSRZSLXWIQB-UHFFFAOYSA-N
# 2    InChiKey=WDENQIQQYWYTPO-IBGZPJMESA-N
# 3    InChiKey=DOCINCLJNAXZQF-LBPRGKRZSA-N
# 4    InChiKey=VGUSQKZDZHAAEE-UHFFFAOYSA-N
# ..                                    ...
# 213  InChiKey=JUSFANSTBFGBAF-IRXDYDNUSA-N
# 214  InChiKey=SXNJFOWDRLKDSF-STROYTFGSA-N
# 215  InChiKey=MRPGRAKIAJJGMM-OCCSQVGLSA-N
# 216  InChiKey=RGHYDLZMTYDBDT-UHFFFAOYSA-N
# 217  InChiKey=RNOAOAWBMHREKO-UHFFFAOYSA-N
#
# [218 rows x 11 columns]

# %%
#This leaves a now redundant Canonical_Smiles_InChiKey column so we remove that from that dataframe.
df = df.drop(columns=['Canonical_Smiles_InChiKey'])
df
# Out:
#           INN_Name  RoF     MW  LogP   TPSA  HBA  HBD  NRB  \
# 0      Abemaciclib    1  506.3   4.9   75.0    8    1    7
# 1      Abivertinib    0  487.2   4.5   98.4    7    3    7
# 2    Acalabrutinib    0  465.2   3.3  118.5    7    2    4
# 3         Acalisib    0  401.1   3.4  101.4    7    2    4
# 4       Acumapimod    0  385.2   2.8  113.8    6    2    5
# ..             ...  ...    ...   ...    ...  ...  ...  ...
# 213    Vistusertib    0  462.2   2.5   92.7    8    1    4
# 214     Volasertib    1  618.4   4.3  106.2    9    2   10
# 215     Voruciclib    0  469.1   4.3   94.1    6    3    3
# 216     Voxtalisib    0  270.1   1.1  102.5    6    2    2
# 217   Zanubrutinib    0  471.2   4.2  102.5    6    2    6
#
#                                                 Smiles  \
# 0    Smiles=CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc...
# 1    Smiles=CN1CCN(CC1)c2ccc(cc2F)Nc3nc4c(cc[nH]4)c...
# 2    Smiles=CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4c...
# 3    Smiles=C[C@@H](c1nc2ccc(cc2c(=O)n1c3ccccc3)F)N...
# 4    Smiles=Cc1ccc(cc1n2c(c(cn2)C(=O)c3cccc(c3)C#N)...
# ..                                                 ...
# 213  Smiles=C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@...
# 214  Smiles=CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3...
# 215  Smiles=CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=...
# 216      Smiles=CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
# 217  Smiles=C=CC(=O)N1CCC(CC1)C2CCNc3n2nc(c3C(=O)N)...
#
#                                 InChi_Key
# 0    InChiKey=UZWDCWONPYILKI-UHFFFAOYSA-N
# 1    InChiKey=UOFYSRZSLXWIQB-UHFFFAOYSA-N
# 2    InChiKey=WDENQIQQYWYTPO-IBGZPJMESA-N
# 3    InChiKey=DOCINCLJNAXZQF-LBPRGKRZSA-N
# 4    InChiKey=VGUSQKZDZHAAEE-UHFFFAOYSA-N
# ..                                    ...
# 213  InChiKey=JUSFANSTBFGBAF-IRXDYDNUSA-N
# 214  InChiKey=SXNJFOWDRLKDSF-STROYTFGSA-N
# 215  InChiKey=MRPGRAKIAJJGMM-OCCSQVGLSA-N
# 216  InChiKey=RGHYDLZMTYDBDT-UHFFFAOYSA-N
# 217  InChiKey=RNOAOAWBMHREKO-UHFFFAOYSA-N
#
# [218 rows x 10 columns]

# %% [markdown]
# The data in both our Smiles and InChi_Key could be cleaned up a bit as the data has 'Smiles=' and 'InChiKey=' in them that could be removed. So we look to clean them here.

# %%
#We put the values in the Smiles and InChi_Key columns in variables.
SmilesList = df['Smiles'].values
InCHIList = df['InChi_Key'].values

#Apply a substitution regex to select the 'Smiles=' and 'InChiKey=' in each of those columns and replace them with blanks. 
Smiles_regex = [re.sub('(Smiles=)', '', Smile) for Smile in SmilesList]
InCHI_regex = [re.sub('(InChiKey=)', '', InCHI) for InCHI in InCHIList]

#We remove the old Smiles and InChi_Key columns
df = df.drop(columns=['Smiles', 'InChi_Key'])

#We then add the new Smiles and InChi_Key columns filled with our regex cleaned data lists.
df['Smiles'] = Smiles_regex
df['InChi_Key'] = InCHI_regex

# %%
#Now we merge our dataframe into the dataframe template and format we actually want (df1)
df1 = pd.merge(df1,df[['INN_Name', 'RoF', 'MW', 'LogP', 'TPSA', 'HBA', 'HBD', 'NRB', 'Smiles', 'InChi_Key' ]],
               on='INN_Name', how='inner')
df1
# Out:
#           INN_Name Targets  RoF     MW  LogP   TPSA  HBA  HBD  NRB  \
# 0      Abemaciclib    CDK4    1  506.3   4.9   75.0    8    1    7
# 1      Abemaciclib    CDK6    1  506.3   4.9   75.0    8    1    7
# 2    Acalabrutinib     BTK    0  465.2   3.3  118.5    7    2    4
# 3         Acalisib  PIK3CA    0  401.1   3.4  101.4    7    2    4
# 4       Acumapimod  MAPK14    0  385.2   2.8  113.8    6    2    5
# ..             ...     ...  ...    ...   ...    ...  ...  ...  ...
# 488    Vistusertib    MTOR    0  462.2   2.5   92.7    8    1    4
# 489     Volasertib    PLK1    1  618.4   4.3  106.2    9    2   10
# 490     Voruciclib    CDK4    0  469.1   4.3   94.1    6    3    3
# 491     Voxtalisib  PIK3CA    0  270.1   1.1  102.5    6    2    2
# 492     Voxtalisib    MTOR    0  270.1   1.1  102.5    6    2    2
#
#                                                 Smiles  \
# 0    CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc5c(c(c4...
# 1    CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc5c(c(c4...
# 2    CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4ccc(cc4)...
# 3    C[C@@H](c1nc2ccc(cc2c(=O)n1c3ccccc3)F)Nc4c5c(n...
# 4    Cc1ccc(cc1n2c(c(cn2)C(=O)c3cccc(c3)C#N)N)C(=O)...
# ..                                                 ...
# 488  C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@@H]4C)c...
# 489  CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3)C(=O)N...
# 490  CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=O)c4ccc...
# 491             CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
# 492             CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
#
#                        InChi_Key
# 0    UZWDCWONPYILKI-UHFFFAOYSA-N
# 1    UZWDCWONPYILKI-UHFFFAOYSA-N
# 2    WDENQIQQYWYTPO-IBGZPJMESA-N
# 3    DOCINCLJNAXZQF-LBPRGKRZSA-N
# 4    VGUSQKZDZHAAEE-UHFFFAOYSA-N
# ..                           ...
# 488  JUSFANSTBFGBAF-IRXDYDNUSA-N
# 489  SXNJFOWDRLKDSF-STROYTFGSA-N
# 490  MRPGRAKIAJJGMM-OCCSQVGLSA-N
# 491  RGHYDLZMTYDBDT-UHFFFAOYSA-N
# 492  RGHYDLZMTYDBDT-UHFFFAOYSA-N
#
# [493 rows x 11 columns]

# %% [markdown]
# Now that we have a large portion of our data in the correct format in our new dataframe we are still missing two details that we want to include:
#
# 1) ChEMBL IDs for each of the inhibitors
#
# 2) Images of the Chemical Structures for each of the inhibitors

# %%
#To obtain the ChEMBL IDs we use BeautifulSoup to parse the html of the PKIDB website 
r = requests.get("http://www.icoa.fr/pkidb/")
soup = BeautifulSoup(r.text, 'html.parser')

#Searching for all 'tr' tags to obtain all of the table rows of the website and place them into an object
table_rows = soup.find_all('tr')

#we then specify the specific rows of the table that actually contain the data we want i.e. all but the very first one (i.e.
# the header in this case [0])
data_rows = table_rows[1:]

# %%
#Set up an empty list to collect all of the Inhibitor Names and their corresponding ChEMBL IDs.
Name_and_ChEMBLIDs = []

for row in data_rows: #for each row in our table rows containing data
    Name = row.find('td').text #extract the text of the table table data tag (Inhibitor name) and put it into a variable.
    ChEMBL = row.find_all('a')[1] #extract the 2nd 'a' tag in the data (ChEMBL link) and put it into a variable
    ChEMBL = str(ChEMBL) #convert it into a string
    ChEMBL_regex = re.search(r"(CHEMBL\d+)",ChEMBL) #use a regex to search for just the ChEMBL ID from the whole url.
    if ChEMBL_regex is not None: #if the regex finds a match
        ChEMBL_regex = ChEMBL_regex.group(0) #extract the match value
    else:
        continue 
        
    Name_and_ChEMBLIDs.append((Name, ChEMBL_regex)) #then append both the name and the ID into our empty list.

# %%
#We then create a new dataframe with the Inhibitor Names and their corresponding ChEMBL IDs 
ChEMBL_ID = pd.DataFrame(Name_and_ChEMBLIDs, columns=['INN_Name', 'ChEMBL_ID'])
ChEMBL_ID
# Out:
#         INN_Name      ChEMBL_ID
# 0     Leniolisib  CHEMBL3643413
# 1    Nemiralisib  CHEMBL2216859
# 2    Oclacitinib  CHEMBL2103874
# 3      Toceranib    CHEMBL13608
# 4    Dezapelisib  CHEMBL2216863
# ..           ...            ...
# 192     Imatinib      CHEMBL941
# 193    Ponatinib  CHEMBL1171837
# 194    Lapatinib      CHEMBL554
# 195   Ribociclib  CHEMBL3545110
# 196  Midostaurin   CHEMBL608533
#
# [197 rows x 2 columns]

# %%
#We then merge this dataframe with the dataframe containing the majority of our data.
df1 = pd.merge(df1,chembl_id[['INN_Name', 'ChEMBL_ID']],
               on='INN_Name', how='inner')
df1
# Out:
#           INN_Name Targets  RoF     MW  LogP   TPSA  HBA  HBD  NRB  \
# 0      Abemaciclib    CDK4    1  506.3   4.9   75.0    8    1    7
# 1      Abemaciclib    CDK6    1  506.3   4.9   75.0    8    1    7
# 2    Acalabrutinib     BTK    0  465.2   3.3  118.5    7    2    4
# 3      Adavosertib    WEE1    1  500.3   2.9  104.3   10    2    7
# 4         Afatinib    EGFR    0  485.2   4.4   88.6    7    2    8
# ..             ...     ...  ...    ...   ...    ...  ...  ...  ...
# 464    Vistusertib    MTOR    0  462.2   2.5   92.7    8    1    4
# 465     Volasertib    PLK1    1  618.4   4.3  106.2    9    2   10
# 466     Voruciclib    CDK4    0  469.1   4.3   94.1    6    3    3
# 467     Voxtalisib  PIK3CA    0  270.1   1.1  102.5    6    2    2
# 468     Voxtalisib    MTOR    0  270.1   1.1  102.5    6    2    2
#
#                                                 Smiles  \
# 0    CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc5c(c(c4...
# 1    CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc5c(c(c4...
# 2    CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4ccc(cc4)...
# 3    CC(C)(c1cccc(n1)n2c3c(cnc(n3)Nc4ccc(cc4)N5CCN(...
# 4    CN(C)C/C=C/C(=O)Nc1cc2c(cc1O[C@H]3CCOC3)ncnc2N...
# ..                                                 ...
# 464  C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@@H]4C)c...
# 465  CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3)C(=O)N...
# 466  CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=O)c4ccc...
# 467             CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
# 468             CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
#
#                        InChi_Key      ChEMBL_ID
# 0    UZWDCWONPYILKI-UHFFFAOYSA-N  CHEMBL3301610
# 1    UZWDCWONPYILKI-UHFFFAOYSA-N  CHEMBL3301610
# 2    WDENQIQQYWYTPO-IBGZPJMESA-N  CHEMBL3707348
# 3    BKWJAKQVGHWELA-UHFFFAOYSA-N  CHEMBL1976040
# 4    ULXXDDBFHOBEHA-CWDCEQMOSA-N  CHEMBL1173655
# ..                           ...            ...
# 464  JUSFANSTBFGBAF-IRXDYDNUSA-N  CHEMBL2336325
# 465  SXNJFOWDRLKDSF-STROYTFGSA-N  CHEMBL1233528
# 466  MRPGRAKIAJJGMM-OCCSQVGLSA-N  CHEMBL3905910
# 467  RGHYDLZMTYDBDT-UHFFFAOYSA-N  CHEMBL3545366
# 468  RGHYDLZMTYDBDT-UHFFFAOYSA-N  CHEMBL3545366
#
# [469 rows x 12 columns]

# %%
#Create an empty list to contain all of our Inhibitor structure image links
image_list = []

for Name in df1['INN_Name']: #for each Inhibitor under the INN_Name column of our main dataframe
    image_link = "http://www.icoa.fr/pkidb/static/img/mol/"+Name+".svg" #create the image link by inserting the inhibitor name
                                                                        #into a url template
    image_list.append(image_link) #then apend that image link into our list

#Then we simply create an image link new column in our dataframe with the contents of the column being our list of image links     
df1["image_link"] = image_list 
df1
# Out:
#           INN_Name Targets  RoF     MW  LogP   TPSA  HBA  HBD  NRB  \
# 0      Abemaciclib    CDK4    1  506.3   4.9   75.0    8    1    7
# 1      Abemaciclib    CDK6    1  506.3   4.9   75.0    8    1    7
# 2    Acalabrutinib     BTK    0  465.2   3.3  118.5    7    2    4
# 3      Adavosertib    WEE1    1  500.3   2.9  104.3   10    2    7
# 4         Afatinib    EGFR    0  485.2   4.4   88.6    7    2    8
# ..             ...     ...  ...    ...   ...    ...  ...  ...  ...
# 464    Vistusertib    MTOR    0  462.2   2.5   92.7    8    1    4
# 465     Volasertib    PLK1    1  618.4   4.3  106.2    9    2   10
# 466     Voruciclib    CDK4    0  469.1   4.3   94.1    6    3    3
# 467     Voxtalisib  PIK3CA    0  270.1   1.1  102.5    6    2    2
# 468     Voxtalisib    MTOR    0  270.1   1.1  102.5    6    2    2
#
#                                                 Smiles  \
# 0    CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc5c(c(c4...
# 1    CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc5c(c(c4...
# 2    CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4ccc(cc4)...
# 3    CC(C)(c1cccc(n1)n2c3c(cnc(n3)Nc4ccc(cc4)N5CCN(...
# 4    CN(C)C/C=C/C(=O)Nc1cc2c(cc1O[C@H]3CCOC3)ncnc2N...
# ..                                                 ...
# 464  C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@@H]4C)c...
# 465  CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3)C(=O)N...
# 466  CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=O)c4ccc...
# 467             CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
# 468             CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
#
#                        InChi_Key      ChEMBL_ID  \
# 0    UZWDCWONPYILKI-UHFFFAOYSA-N  CHEMBL3301610
# 1    UZWDCWONPYILKI-UHFFFAOYSA-N  CHEMBL3301610
# 2    WDENQIQQYWYTPO-IBGZPJMESA-N  CHEMBL3707348
# 3    BKWJAKQVGHWELA-UHFFFAOYSA-N  CHEMBL1976040
# 4    ULXXDDBFHOBEHA-CWDCEQMOSA-N  CHEMBL1173655
# ..                           ...            ...
# 464  JUSFANSTBFGBAF-IRXDYDNUSA-N  CHEMBL2336325
# 465  SXNJFOWDRLKDSF-STROYTFGSA-N  CHEMBL1233528
# 466  MRPGRAKIAJJGMM-OCCSQVGLSA-N  CHEMBL3905910
# 467  RGHYDLZMTYDBDT-UHFFFAOYSA-N  CHEMBL3545366
# 468  RGHYDLZMTYDBDT-UHFFFAOYSA-N  CHEMBL3545366
#
#                                             image_link
# 0    http://www.icoa.fr/pkidb/static/img/mol/Abemac...
# 1    http://www.icoa.fr/pkidb/static/img/mol/Abemac...
# 2    http://www.icoa.fr/pkidb/static/img/mol/Acalab...
# 3    http://www.icoa.fr/pkidb/static/img/mol/Adavos...
# 4    http://www.icoa.fr/pkidb/static/img/mol/Afatin...
# ..                                                 ...
# 464  http://www.icoa.fr/pkidb/static/img/mol/Vistus...
# 465  http://www.icoa.fr/pkidb/static/img/mol/Volase...
# 466  http://www.icoa.fr/pkidb/static/img/mol/Voruci...
# 467  http://www.icoa.fr/pkidb/static/img/mol/Voxtal...
# 468  http://www.icoa.fr/pkidb/static/img/mol/Voxtal...
#
# [469 rows x 13 columns]

# %%
#Finally, we insert another column to act as our ID column so that we have a primary key for our inhibtor table for our database
df1.insert(0, 'INHIBITOR_ID', range(1, 1 + len(df1)))
df1
# Out:
#      INHIBITOR_ID       INN_Name Targets  RoF     MW  LogP   TPSA  HBA  HBD  \
# 0               1    Abemaciclib    CDK4    1  506.3   4.9   75.0    8    1
# 1               2    Abemaciclib    CDK6    1  506.3   4.9   75.0    8    1
# 2               3  Acalabrutinib     BTK    0  465.2   3.3  118.5    7    2
# 3               4    Adavosertib    WEE1    1  500.3   2.9  104.3   10    2
# 4               5       Afatinib    EGFR    0  485.2   4.4   88.6    7    2
# ..            ...            ...     ...  ...    ...   ...    ...  ...  ...
# 464           465    Vistusertib    MTOR    0  462.2   2.5   92.7    8    1
# 465           466     Volasertib    PLK1    1  618.4   4.3  106.2    9    2
# 466           467     Voruciclib    CDK4    0  469.1   4.3   94.1    6    3
# 467           468     Voxtalisib  PIK3CA    0  270.1   1.1  102.5    6    2
# 468           469     Voxtalisib    MTOR    0  270.1   1.1  102.5    6    2
#
#      NRB                                             Smiles  \
# 0      7  CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc5c(c(c4...
# 1      7  CCN1CCN(CC1)Cc2ccc(nc2)Nc3ncc(c(n3)c4cc5c(c(c4...
# 2      4  CC#CC(=O)N1CCC[C@H]1c2nc(c3n2ccnc3N)c4ccc(cc4)...
# 3      7  CC(C)(c1cccc(n1)n2c3c(cnc(n3)Nc4ccc(cc4)N5CCN(...
# 4      8  CN(C)C/C=C/C(=O)Nc1cc2c(cc1O[C@H]3CCOC3)ncnc2N...
# ..   ...                                                ...
# 464    4  C[C@H]1COCCN1c2c3ccc(nc3nc(n2)N4CCOC[C@@H]4C)c...
# 465   10  CC[C@H]1N(c2nc(ncc2N(C1=O)C)Nc3c(cc(cc3)C(=O)N...
# 466    3  CN1CC[C@H]([C@@H]1CO)c2c(cc(c3c2oc(cc3=O)c4ccc...
# 467    2             CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
# 468    2             CCn1c2c(cc(c1=O)c3ccn[nH]3)c(nc(n2)N)C
#
#                        InChi_Key      ChEMBL_ID  \
# 0    UZWDCWONPYILKI-UHFFFAOYSA-N  CHEMBL3301610
# 1    UZWDCWONPYILKI-UHFFFAOYSA-N  CHEMBL3301610
# 2    WDENQIQQYWYTPO-IBGZPJMESA-N  CHEMBL3707348
# 3    BKWJAKQVGHWELA-UHFFFAOYSA-N  CHEMBL1976040
# 4    ULXXDDBFHOBEHA-CWDCEQMOSA-N  CHEMBL1173655
# ..                           ...            ...
# 464  JUSFANSTBFGBAF-IRXDYDNUSA-N  CHEMBL2336325
# 465  SXNJFOWDRLKDSF-STROYTFGSA-N  CHEMBL1233528
# 466  MRPGRAKIAJJGMM-OCCSQVGLSA-N  CHEMBL3905910
# 467  RGHYDLZMTYDBDT-UHFFFAOYSA-N  CHEMBL3545366
# 468  RGHYDLZMTYDBDT-UHFFFAOYSA-N  CHEMBL3545366
#
#                                             image_link
# 0    http://www.icoa.fr/pkidb/static/img/mol/Abemac...
# 1    http://www.icoa.fr/pkidb/static/img/mol/Abemac...
# 2    http://www.icoa.fr/pkidb/static/img/mol/Acalab...
# 3    http://www.icoa.fr/pkidb/static/img/mol/Adavos...
# 4    http://www.icoa.fr/pkidb/static/img/mol/Afatin...
# ..                                                 ...
# 464  http://www.icoa.fr/pkidb/static/img/mol/Vistus...
# 465  http://www.icoa.fr/pkidb/static/img/mol/Volase...
# 466  http://www.icoa.fr/pkidb/static/img/mol/Voruci...
# 467  http://www.icoa.fr/pkidb/static/img/mol/Voxtal...
# 468  http://www.icoa.fr/pkidb/static/img/mol/Voxtal...
#
# [469 rows x 14 columns]

# %%
#Writing our final dataframe into a CSV file
df1.to_csv('Inhibitor_Table.csv')
